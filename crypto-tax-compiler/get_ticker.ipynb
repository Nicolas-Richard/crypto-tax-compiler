# %%
import requests

response = requests.get('https://api.coinmarketcap.com/v1/ticker/')
print(format(response.json()))
# Out:
# [{'id': 'bitcoin', 'name': 'Bitcoin', 'symbol': 'BTC', 'rank': '1', 'price_usd': '4769.96', 'price_btc': '1.0', '24h_volume_usd': '1513790000.0', 'market_cap_usd': '79259086348.0', 'available_supply': '16616300.0', 'total_supply': '16616300.0', 'percent_change_1h': '0.16', 'percent_change_24h': '-0.89', 'percent_change_7d': '10.6', 'last_updated': '1507697953'}, {'id': 'ethereum', 'name': 'Ethereum', 'symbol': 'ETH', 'rank': '2', 'price_usd': '302.453', 'price_btc': '0.0636827', '24h_volume_usd': '332878000.0', 'market_cap_usd': '28748134739.0', 'available_supply': '95049924.0', 'total_supply': '95049924.0', 'percent_change_1h': '0.09', 'percent_change_24h': '1.51', 'percent_change_7d': '2.64', 'last_updated': '1507697949'}, {'id': 'ripple', 'name': 'Ripple', 'symbol': 'XRP', 'rank': '3', 'price_usd': '0.26146', 'price_btc': '0.00005505', '24h_volume_usd': '326936000.0', 'market_cap_usd': '10092474035.0', 'available_supply': '38600451446.0', 'total_supply': '99993285884.0', 'percent_
# ...
